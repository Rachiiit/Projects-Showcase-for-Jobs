# %%
import pandas as pd

# %%
dfd = pd.read_csv('International_Report_Departures.csv')

# %%
dfp = pd.read_csv('International_Report_Passengers.csv')

# %%
dfd.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2006  2006      5     12016.0     GUM      5.0    13162.0    MAJ
# 1  05/01/2003  2003      5     10299.0     ANC      1.0    13856.0    OKO
# 2  03/01/2007  2007      3     10721.0     BOS     13.0    12651.0    KEF
# 3  12/01/2004  2004     12     11259.0     DAL     74.0    16271.0    YYZ
# 4  05/01/2009  2009      5     13303.0     MIA     33.0    11075.0    CMW
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0   844.0    20177.0     PFQ           1.0  Departures        0.0     10.0
# 1   736.0    20007.0      5Y           1.0  Departures        0.0     15.0
# 2   439.0    20402.0      GL           1.0  Departures        0.0      1.0
# 3   936.0    20201.0     AMQ           1.0  Departures        0.0      1.0
# 4   219.0    21323.0      5L           0.0  Departures        0.0     20.0
#
#    Total
# 0   10.0
# 1   15.0
# 2    1.0
# 3    1.0
# 4   20.0

# %%
dfp.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1  06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3  04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76

# %%
dfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398352 entries, 0 to 398351
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_dte      398352 non-null  object
#  1   Year          398352 non-null  int64
#  2   Month         398352 non-null  int64
#  3   usg_apt_id    398351 non-null  float64
#  4   usg_apt       398351 non-null  object
#  5   usg_wac       398351 non-null  float64
#  6   fg_apt_id     398351 non-null  float64
#  7   fg_apt        398351 non-null  object
#  8   fg_wac        398351 non-null  float64
#  9   airlineid     398351 non-null  float64
#  10  carrier       396931 non-null  object
#  11  carriergroup  398351 non-null  float64
#  12  type          398351 non-null  object
#  13  Scheduled     398351 non-null  float64
#  14  Charter       398351 non-null  float64
#  15  Total         398351 non-null  float64
# dtypes: float64(9), int64(2), object(5)
# memory usage: 48.6+ MB

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364160 entries, 0 to 364159
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_dte      364160 non-null  object
#  1   Year          364160 non-null  int64
#  2   Month         364160 non-null  int64
#  3   usg_apt_id    364160 non-null  int64
#  4   usg_apt       364160 non-null  object
#  5   usg_wac       364160 non-null  int64
#  6   fg_apt_id     364160 non-null  int64
#  7   fg_apt        364160 non-null  object
#  8   fg_wac        364160 non-null  int64
#  9   airlineid     364160 non-null  int64
#  10  carrier       361919 non-null  object
#  11  carriergroup  364160 non-null  int64
#  12  type          364160 non-null  object
#  13  Scheduled     364160 non-null  int64
#  14  Charter       364160 non-null  int64
#  15  Total         364160 non-null  int64
# dtypes: int64(11), object(5)
# memory usage: 44.5+ MB

# %%
dfd.isnull().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         1
# usg_apt            1
# usg_wac            1
# fg_apt_id          1
# fg_apt             1
# fg_wac             1
# airlineid          1
# carrier         1421
# carriergroup       1
# type               1
# Scheduled          1
# Charter            1
# Total              1
# dtype: int64

# %%
dfp.isnull().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         2241
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
dfd['type'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 398347    False
# 398348    False
# 398349    False
# 398350    False
# 398351     True
# Name: type, Length: 398352, dtype: bool

# %%
dfd[dfd['type'].isnull()]
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 398351  03/01/1992  1992      3         NaN     NaN      NaN        NaN
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup type  Scheduled  \
# 398351    NaN     NaN        NaN     NaN           NaN  NaN        NaN
#
#         Charter  Total
# 398351      NaN    NaN

# %%
dfd.drop(113542, inplace=True)

# %%
dfd[dfd['type'].isnull()]
# Out:
#           data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id  \
# 398351  03/01/1992  1992      3         NaN     NaN      NaN        NaN
#
#        fg_apt  fg_wac  airlineid carrier  carriergroup type  Scheduled  \
# 398351    NaN     NaN        NaN     NaN           NaN  NaN        NaN
#
#         Charter  Total
# 398351      NaN    NaN

# %%
dfd.isnull().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         1
# usg_apt            1
# usg_wac            1
# fg_apt_id          1
# fg_apt             1
# fg_wac             1
# airlineid          1
# carrier         1421
# carriergroup       1
# type               1
# Scheduled          1
# Charter            1
# Total              1
# dtype: int64

# %%
dfp[dfp['type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [data_dte, Year, Month, usg_apt_id, usg_apt, usg_wac, fg_apt_id, fg_apt, fg_wac, airlineid, carrier, carriergroup, type, Scheduled, Charter, Total]
# Index: []

# %%
dfp[dfp['type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [data_dte, Year, Month, usg_apt_id, usg_apt, usg_wac, fg_apt_id, fg_apt, fg_wac, airlineid, carrier, carriergroup, type, Scheduled, Charter, Total]
# Index: []

# %%
dfp.drop(121924, inplace=True)

# %%
dfp[dfp['type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [data_dte, Year, Month, usg_apt_id, usg_apt, usg_wac, fg_apt_id, fg_apt, fg_wac, airlineid, carrier, carriergroup, type, Scheduled, Charter, Total]
# Index: []

# %%
dfp.isnull().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         2241
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
dfp[dfp.duplicated()]
# Out:
# Empty DataFrame
# Columns: [data_dte, Year, Month, usg_apt_id, usg_apt, usg_wac, fg_apt_id, fg_apt, fg_wac, airlineid, carrier, carriergroup, type, Scheduled, Charter, Total]
# Index: []

# %%
dfd[dfd.duplicated()]
# Out:
# Empty DataFrame
# Columns: [data_dte, Year, Month, usg_apt_id, usg_apt, usg_wac, fg_apt_id, fg_apt, fg_wac, airlineid, carrier, carriergroup, type, Scheduled, Charter, Total]
# Index: []

# %%
dfd.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2006  2006      5     12016.0     GUM      5.0    13162.0    MAJ
# 1  05/01/2003  2003      5     10299.0     ANC      1.0    13856.0    OKO
# 2  03/01/2007  2007      3     10721.0     BOS     13.0    12651.0    KEF
# 3  12/01/2004  2004     12     11259.0     DAL     74.0    16271.0    YYZ
# 4  05/01/2009  2009      5     13303.0     MIA     33.0    11075.0    CMW
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0   844.0    20177.0     PFQ           1.0  Departures        0.0     10.0
# 1   736.0    20007.0      5Y           1.0  Departures        0.0     15.0
# 2   439.0    20402.0      GL           1.0  Departures        0.0      1.0
# 3   936.0    20201.0     AMQ           1.0  Departures        0.0      1.0
# 4   219.0    21323.0      5L           0.0  Departures        0.0     20.0
#
#    Total
# 0   10.0
# 1   15.0
# 2    1.0
# 3    1.0
# 4   20.0

# %%
dfd.fillna(dfd.mode().iloc[0], inplace=True)

# %%
dfp.fillna(dfp.mode().iloc[0], inplace=True)

# %%
dfd.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
dfp.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
dfd.describe(
)
# Out:
#                 Year          Month     usg_apt_id        usg_wac  \
# count  398351.000000  398351.000000  398351.000000  398351.000000
# mean     2005.130588       6.384415   12943.522951      40.925154
# std         8.574196       3.481535    3868.870928      25.814976
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1998.000000       3.000000   11618.000000      22.000000
# 50%      2005.000000       6.000000   13061.000000      33.000000
# 75%      2012.000000       9.000000   13871.000000      63.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  398351.000000  398351.000000  398351.000000  398351.000000
# mean    13600.470326     462.576466   20194.036917       0.677626
# std      1974.439240     296.869995     491.080176       0.467386
# min     10119.000000     106.000000   19386.000000       0.000000
# ...

# %%
sns.barplot(x='usg_apt', y='Total', data=dfp)
# Out:
# <Axes: xlabel='usg_apt', ylabel='Total'>

# %%
sns.barplot(x='usg_apt', y='Total', data=dfd)
# Out:
# <Axes: xlabel='usg_apt', ylabel='Total'>

# %%
sns.barplot(x='carrier', y='Total', data=dfd)
# Out:
# <Axes: xlabel='carrier', ylabel='Total'>

# %%
sns.barplot(x='carrier', y='Total', data=dfp)
# Out:
# <Axes: xlabel='carrier', ylabel='Total'>

# %%
sns.barplot(x='fg_apt', y='Total', data=dfd)
# Out:
# <Axes: xlabel='fg_apt', ylabel='Total'>

# %%
sns.barplot(x='fg_apt', y='Total', data=dfp)
# Out:
# <Axes: xlabel='fg_apt', ylabel='Total'>

# %%
sns.lineplot(x='Year', y='Total', data=dfd)
# Out:
# <Axes: xlabel='Year', ylabel='Total'>

# %%
sns.lineplot(x='Year', y='Total', data=dfp)
# Out:
# <Axes: xlabel='Year', ylabel='Total'>
